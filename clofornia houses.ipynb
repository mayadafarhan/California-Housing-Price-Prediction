# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
df=fetch_california_housing(as_frame=True)
df=df.frame
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
sns.histplot(df["MedHouseVal"],bins=50, kde=True)
# Out:
# <Axes: xlabel='MedHouseVal', ylabel='Count'>

# %%
sns.scatterplot(x='MedInc',y='MedHouseVal',data=df)
# Out:
# <Axes: xlabel='MedInc', ylabel='MedHouseVal'>

# %%
corr=df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
sns.barplot(x='Longitude',hue='Latitude',data=df)
# Out:
# <Axes: xlabel='Longitude'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df[df['AveRooms']>10]
# Out:
#        MedInc  HouseAge   AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1023   2.2417      15.0  10.515306   2.372449       573.0  2.923469     38.72
# 1024   3.1500      16.0  29.852941   5.323529       202.0  1.980392     38.52
# 1030   3.0125      15.0  10.168591   2.057737      1103.0  2.547344     38.55
# 1102   2.4028      17.0  31.777778   9.703704        47.0  1.740741     40.06
# 1233   3.7500      10.0  16.847534   3.237668       546.0  2.448430     38.23
# ...       ...       ...        ...        ...         ...       ...       ...
# 20093  2.0625      37.0  24.669118   4.897059       338.0  2.485294     38.12
# 20094  2.1250      26.0  37.063492   7.185185       416.0  2.201058     38.19
# 20110  3.2589       9.0  11.458508   2.056161      2811.0  2.356245     37.84
# 20112  4.0833      18.0  11.536585   2.804878        88.0  2.146341     37.85
# 20113  3.4861      17.0  17.300000   6.500000        51.0  2.550000     37.94
#
#        Longitude  MedHouseVal
# ...

# %%
sns.histplot(df['MedHouseVal'], bins=50, kde=True, color='blue')
# Out:
# <Axes: xlabel='MedHouseVal', ylabel='Count'>

# %% [markdown]
# ### العلاقه بين دخل الفرد وقيمه المنزل

# %%
sns.scatterplot(x='MedInc', y='MedHouseVal', data=df)
# Out:
# <Axes: xlabel='MedInc', ylabel='MedHouseVal'>

# %% [markdown]
# ## العلاقه بين عمر المنزل وقيمه المنزل

# %%
sns.scatterplot(x='HouseAge', y='MedHouseVal', data=df)
# Out:
# <Axes: xlabel='HouseAge', ylabel='MedHouseVal'>

# %%
df['MedHouseVal'].mean()
# Out:
# np.float64(2.068558169089147)

# %%
sns.scatterplot(x='AveBedrms', y='AveRooms', data=df)
plt.xlabel('AveBedrms')
plt.ylabel('AveRooms')
plt.show()

# %%
plt.boxplot(df['HouseAge'])
plt.show()

# %%
sns.boxplot(x='Latitude', y='MedHouseVal')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.boxplot(x='Latitude', y='MedHouseVal')
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
#    1602         color=color,
# ...

# %%
df['MedHouseVal'].max()
# Out:
# 5.00001

# %%
sns.scatterplot(x='HouseAge',y="Population",data= df)
# Out:
# <Axes: xlabel='HouseAge', ylabel='Population'>

# %%
corr_value = df['Population'].corr(df['MedInc']) 
print( corr_value)
# Out:
# 0.004834345627652914

# %%
sns.scatterplot(x='Population', y='MedInc', data=df, color='orange')
# Out:
# <Axes: xlabel='Population', ylabel='MedInc'>

# %%
sns.histplot(df['Population'],bins=30,kde=True)
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.countplot(data=df,x='Population' )
# Out:
# <Axes: xlabel='Population', ylabel='count'>
